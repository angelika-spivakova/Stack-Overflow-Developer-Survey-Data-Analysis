# %%
import pandas as pd    ### Імпортуємо бібліотеку Pandas

# %%
  ### Читаємо файли csv 
public_df = pd.read_csv(r'C:\Users\Angelika\Downloads\stack-overflow-developer-survey-2025\survey_results_public.csv', encoding='utf-8')
schema_df = pd.read_csv(r'C:\Users\Angelika\Downloads\stack-overflow-developer-survey-2025\survey_results_schema.csv', encoding='utf-8')
# Out:
# C:\Users\Angelika\AppData\Local\Temp\ipykernel_17176\2278874296.py:1: DtypeWarning: Columns (56,74,92,97,98,105,109,110,132,162,165) have mixed types. Specify dtype option on import or set low_memory=False.
#   public_df = pd.read_csv(r'C:\Users\Angelika\Downloads\stack-overflow-developer-survey-2025\survey_results_public.csv', encoding='utf-8')

# %%
   ## Дивимося всі колонки великого DataFrame без обрізання ( не прив’язується до конкретного DataFrame)
                              ## це глобальна настройка для Pandas
pd.set_option('display.max_columns', None)

# %%
  ## Виводимо наглядно таблицю 1
public_df.head()
# Out:
#    ResponseId                      MainBranch              Age  \
# 0           1  I am a developer by profession  25-34 years old
# 1           2  I am a developer by profession  25-34 years old
# 2           3  I am a developer by profession  35-44 years old
# 3           4  I am a developer by profession  35-44 years old
# 4           5  I am a developer by profession  35-44 years old
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1              Associate degree (A.A., A.S., etc.)
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                           Employment  \
# 0                                           Employed
# 1                                           Employed
# 2  Independent contractor, freelancer, or self-em...
# 3                                           Employed
# ...

# %%
  ## Виводимо наглядно таблицю 2 
schema_df.head()
# Out:
#      qid          qname                                           question  \
# 0  QID18  TechEndorse_1  What attracts you to a technology or causes yo...
# 1  QID18  TechEndorse_2  What attracts you to a technology or causes yo...
# 2  QID18  TechEndorse_3  What attracts you to a technology or causes yo...
# 3  QID18  TechEndorse_4  What attracts you to a technology or causes yo...
# 4  QID18  TechEndorse_5  What attracts you to a technology or causes yo...
#
#   type                                      sub  sq_id
# 0   RO  AI integration or AI Agent capabilities    1.0
# 1   RO                          Easy-to-use API    2.0
# 2   RO                  Robust and complete API    3.0
# 3   RO     Customizable and manageable codebase    4.0
# 4   RO                   Reputation for quality    5.0

# %%
  ## Виводимо інформацію по schema_df

schema_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   qid       139 non-null    object
#  1   qname     139 non-null    object
#  2   question  139 non-null    object
#  3   type      139 non-null    object
#  4   sub       49 non-null     object
#  5   sq_id     49 non-null     float64
# dtypes: float64(1), object(5)
# memory usage: 6.6+ KB

# %%
    ## Виводимо інформацію по public_df

public_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49191 entries, 0 to 49190
# Columns: 172 entries, ResponseId to JobSat
# dtypes: float64(52), int64(1), object(119)
# memory usage: 64.6+ MB

# %%
      ### Завд 1 . Підраховуємо кількість рядків, тобто загальну кількість респондентів.
public_df.shape[0]
# Out:
# 49191

# %%
    ## Виводимо назви стовпців у зручний спосіб
public_df.columns.tolist()
# Out:
# ['ResponseId',
#  'MainBranch',
#  'Age',
#  'EdLevel',
#  'Employment',
#  'EmploymentAddl',
#  'WorkExp',
#  'LearnCodeChoose',
#  'LearnCode',
#  'LearnCodeAI',
#  'AILearnHow',
#  'YearsCode',
#  'DevType',
#  'OrgSize',
#  'ICorPM',
#  'RemoteWork',
#  'PurchaseInfluence',
#  'TechEndorseIntro',
#  'TechEndorse_1',
#  'TechEndorse_2',
#  'TechEndorse_3',
#  'TechEndorse_4',
#  'TechEndorse_5',
#  'TechEndorse_6',
#  'TechEndorse_7',
#  'TechEndorse_8',
#  'TechEndorse_9',
#  'TechEndorse_13',
#  'TechEndorse_13_TEXT',
#  'TechOppose_1',
#  'TechOppose_2',
#  'TechOppose_3',
#  'TechOppose_5',
#  'TechOppose_7',
#  'TechOppose_9',
#  'TechOppose_11',
#  'TechOppose_13',
#  'TechOppose_16',
#  'TechOppose_15',
#  'TechOppose_15_TEXT',
#  'Industry',
#  'JobSatPoints_1',
#  'JobSatPoints_2',
#  'JobSatPoints_3',
#  'JobSatPoints_4',
#  'JobSatPoints_5',
#  'JobSatPoints_6',
#  'JobSatPoints_7',
#  'JobSatPoints_8',
#  'JobSatPoints_9',
#  'JobSatPoints_10',
#  'JobSatPoints_11',
# ...

# %%
 ## рахуємо кількість унікальних значень у колонці Respondent, ( 49191 -співпала із заг. кількістю)
public_df['ResponseId'].nunique()
# Out:
# 49191

# %%
   ###    Завдання 2: аналіз повноти відповідей респондентів

  # 1) Отримуємо список питань з survey_results_schema
questions = schema_df['qname'].unique()

# %%
   # 2) Перетворюємо на множину
questions_set = set(questions)

# %%
  # 3) Знаходимо перетин з колонками public_df
common_columns = questions_set.intersection(set(public_df.columns))

# %%
   # 4) Відбираємо тільки ці колонки та видаляємо рядки з пропусками
complete_respondents = public_df.dropna(subset=common_columns)

# %%
# 5) Підрахунок респондентів, які відповіли на всі питання
complete_respondents_count = complete_respondents.shape[0]

complete_respondents_count
# Out:
# 0

# %%
  ###  Превірка 1 : чи правильно вибрали питання ( Це число покаже, скільки питань з qname реально є в public_df)

len(common_columns)
# Out:
# 126

# %%
 ###  Перевірка 2: чи є пропуски у цих колонках  (Це покаже 5 питань з найбільшою кількістю пропусків)

common_columns_list = list(common_columns)

public_df[common_columns_list].isna().sum().sort_values(ascending=False).head()
# Out:
# AIAgentObsWrite      48927
# SOTagsWant Entry     48761
# SOTagsHaveEntry      48733
# AIModelsWantEntry    48716
# AIAgentOrchWrite     48713
# dtype: int64

# %%
   ###  Завдання 3: статистичний аналіз досвіду респондентів (WorkExp)

workexp = public_df['WorkExp'].dropna()

mean_value = workexp.mean()
median_value = workexp.median()
mode_value = workexp.mode()

print(f"Міри центральної тенденції:")
print(f"Середнє (mean): {mean_value}")
print(f"Медіана (median): {median_value}")
print(f"Мода (mode): {mode_value.tolist()}")
# Out:
# Міри центральної тенденції:
# Середнє (mean): 13.367402606485907
# Медіана (median): 10.0
# Мода (mode): [10.0]

# %%
     ###  Завдання 4. Аналіз віддаленої роботи
     ## Дивимося всі унікальні значення, включно з nan
public_df['RemoteWork'].unique()
# Out:
# array(['Remote', 'Hybrid (some in-person, leans heavy to flexibility)',
#        nan, 'In-person', 'Hybrid (some remote, leans heavy to in-person)',
#        'Your choice (very flexible, you can come in when you want or just as needed)'],
#       dtype=object)

# %%
  ## Перевіряємо, які варіанти є та кількість по кожному типу 

public_df['RemoteWork'].value_counts()
# Out:
# RemoteWork
# Remote                                                                          10931
# Hybrid (some remote, leans heavy to in-person)                                   6732
# In-person                                                                        6042
# Hybrid (some in-person, leans heavy to flexibility)                              5831
# Your choice (very flexible, you can come in when you want or just as needed)     4244
# Name: count, dtype: int64

# %%
  ## Були пропущені відповіді nan , рахуємо зараз скільки їх є. Потім  таких респондентів не враховуватимемо при підрахунку remote

public_df['RemoteWork'].isna().sum()
# Out:
# np.int64(15411)

# %%
 ## Рахуємо число, що показує кількість респондентів, які працюють віддалено ( remote )

remote_count = public_df[public_df['RemoteWork'] == 'Remote'].shape[0]
remote_count
# Out:
# 10931

# %%
      ###  Завдання 5. Визначення популярності Python

 # 1) Створюємо новий стовпець з True/False

public_df['Worked with Python'] = public_df['LanguageHaveWorkedWith'] \
    .str.contains('python', case=False, na=False)

# %%
 # 2) Рахуємо кількість респондентів, які працювали з Python

python_count = public_df['Worked with Python'].sum()

# %%
 # 3) Рахуємо загальну кількість респондентів (без NaN в цій колонці)

total_respondents = public_df.shape[0]

# %%
  # 4) Розрахунок відсотка

python_percentage = (python_count / total_respondents) * 100

# %%
  # 5) Виводимо красиво (f строку )

print(f"Відсоток респондентів, які програмують на Python: {python_percentage:.1f}%")
# Out:
# Відсоток респондентів, які програмують на Python: 37.5%

# %%
     ### Завдання 6. Аналіз шляхів навчання програмуванню

  # 1) Створюємо новий стовпець з True/False

public_df['Learned with online'] = public_df['LearnCode'] \
    .str.contains('online courses', case=False, na=False)

# %%
  # 2) Рахуємо кількість респондентів, які обрали онлайн курси

online_count = public_df['Learned with online'].sum()

# %%
  # 3) Виводимо результат

print("Кількість респондентів, які навчались через онлайн курси:", online_count)
# Out:
# Кількість респондентів, які навчались через онлайн курси: 10973

# %%
    ### Завдання 7. Географічний аналіз компенсації Python-розробників

  # 1) Відбираємо Python-розробників
python_df = public_df[public_df['Worked with Python'] == True]

  # 2) Видаляємо рядки без зарплати
python_df = python_df.dropna(subset=['ConvertedCompYearly'])

  # 3) Групуємо по країні та рахуємо mean і median
compensation_by_country = python_df.groupby('Country')['ConvertedCompYearly'].agg(
    mean_compensation='mean',
    median_compensation='median'
).reset_index()

  # 4) Виводимо таблицю
compensation_by_country
# Out:
#                                   Country  mean_compensation  \
# 0                             Afghanistan       22328.666667
# 1                                 Albania       47217.600000
# 2                                 Algeria       20187.285714
# 3                                 Andorra      226103.500000
# 4                     Antigua and Barbuda           1.000000
# ..                                    ...                ...
# 148  Venezuela, Bolivarian Republic of...        9908.647059
# 149                              Viet Nam      218837.166667
# 150                                 Yemen       32929.500000
# 151                                Zambia        5424.250000
# 152                              Zimbabwe       34000.000000
#
#      median_compensation
# 0                 1000.0
# 1                50000.0
# 2                 7088.0
# 3               226103.5
# 4                    1.0
# ..                   ...
# 148               3000.0
# ...

# %%
   ### Завдання 8. Аналіз освіти найбільш оплачуваних спеціалістів. Визначаємо рівні освіти 5 респондентів з найбільшою компенсацією.

 # 1) Відбираємо потрібні колонки
top_education = public_df[['ResponseId', 'EdLevel', 'ConvertedCompYearly']]

 # 2) Видаляємо пропуски в зарплаті
top_education = top_education.dropna(subset=['ConvertedCompYearly'])

 # 3) Сортуємо за зарплатою у спадному порядку
top_education = top_education.sort_values(
    by='ConvertedCompYearly', 
    ascending=False
).reset_index(drop=True)

 # 4) Беремо топ-5
top_5 = top_education.head(5)

 # 5) Виводимо результат (рівні освіти)
top_5[['ResponseId', 'EdLevel', 'ConvertedCompYearly']]
# Out:
#    ResponseId                                          EdLevel  \
# 0       34268              Associate degree (A.A., A.S., etc.)
# 1       28701  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2       43144              Associate degree (A.A., A.S., etc.)
# 3       35354     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4       45972  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#    ConvertedCompYearly
# 0           50000000.0
# 1           33552715.0
# 2           18387548.0
# 3           15430267.0
# 4           13921760.0

# %%
  ## Або  виводимо результат та показуємо у форматі списку  (другий варіант )

top_5['EdLevel'].tolist()
# Out:
# ['Associate degree (A.A., A.S., etc.)',
#  'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
#  'Associate degree (A.A., A.S., etc.)',
#  'Bachelor’s degree (B.A., B.S., B.Eng., etc.)',
#  'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)']

# %%
    ###  Завдання 9. Аналіз популярності Python по віковим категоріям 
                # Потрібно: 
           ##  Взяти поле Age (вік)
           ## Групувати респондентів за віком
           ## Для кожної групи обчислити:
            # кількість Python-розробників
            # загальну кількість респондентів
            # відсоток Python-розробників

# 1) Переконуємося, що у нас є колонка Worked with Python
# (якщо ще не створена, то створимо)
public_df['Worked with Python'] = public_df['LanguageHaveWorkedWith'] \
    .str.contains('python', case=False, na=False)

# 2) Групуємо по віку та рахуємо відсоток
age_python = public_df.groupby('Age')['Worked with Python'].mean() * 100

# 3) Перетворюємо в таблицю
age_python_df = age_python.reset_index().rename(
    columns={'Worked with Python': 'Python_percentage'}
)

# 4) Виводимо результат
age_python_df
# Out:
#                  Age  Python_percentage
# 0    18-24 years old          40.000000
# 1    25-34 years old          36.939282
# 2    35-44 years old          36.719281
# 3    45-54 years old          38.629482
# 4    55-64 years old          37.242955
# 5  65 years or older          31.634820
# 6  Prefer not to say          31.216931

# %%
   ### Завдання 10. Аналіз індустрій серед високооплачуваних віддалених працівників
              # Що потрібно :
         ## Розрахувати 75-й перцентиль по зарплаті (ConvertedCompYearly)
         ## Відфільтрувати:
           # тих, хто заробляє більше 75% (вище 75 перцентилю)
           # працює Remote
           # Для цієї групи знайти найпопулярніші Industry
           # Підрахувати частоту та відсортувати

# 1) Розрахунок 75 перцентилю
percentile_75 = public_df['ConvertedCompYearly'].quantile(0.75)

# 2) Фільтрація: високооплачувані + Remote
high_paid_remote = public_df[
    (public_df['ConvertedCompYearly'] > percentile_75) &
    (public_df['RemoteWork'] == 'Remote')
]

# 3) Підрахунок найпопулярніших індустрій
industry_counts = high_paid_remote['Industry'].value_counts()

# 4) Вивід результату
industry_counts
# Out:
# Industry
# Software Development                          1186
# Fintech                                        190
# Healthcare                                     188
# Other:                                         176
# Internet, Telecomm or Information Services     138
# Banking/Financial Services                      88
# Government                                      78
# Media & Advertising Services                    75
# Retail and Consumer Services                    65
# Transportation, or Supply Chain                 63
# Computer Systems Design and Services            59
# Insurance                                       46
# Energy                                          45
# Manufacturing                                   33
# Higher Education                                30
# Name: count, dtype: int64
